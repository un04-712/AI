# %%
import numpy as np

"""
    按照值对series进行排序
    Series.sort_values(axis=0, ascending=True,
     inplace=False,kind='quicksort', na_position='last',
      ignore_index=False,key=None)

    axis ：
   ascending：True为升序，False为降序
   inplace：是否在原始series中操作
   kind ： 排序算法
        quicksort：速度最快的，性能平均 但不稳定，最坏的情况下性能较差
        mergesort： 稳定的排序算法，性能较好，但是空间复杂度高
        heapsort: 空间效率较高，但不稳定
        stable： 稳定的排序算法，由mergesort和timesort实现
   na_position: 决定NaN值的放置位置  first放在首位  last放在尾部
   ignore_index： 为True则重置索引
   key：传入函数地址   如果指定，则这个函数将在排序之前应用于每个值，并且排序将基于这些函数返回的值。
"""
import pandas as pd
import numpy as np
# 基本用法
s =  pd.Series([1,4,6,8,-1,4,-56,np.nan,2])
print(s)
# Out:
# 0     1.0
# 1     4.0
# 2     6.0
# 3     8.0
# 4    -1.0
# 5     4.0
# 6   -56.0
# 7     NaN
# 8     2.0
# dtype: float64

# %%
print(s.sort_values())
# Out:
# 6   -56.0
# 4    -1.0
# 0     1.0
# 8     2.0
# 1     4.0
# 5     4.0
# 2     6.0
# 3     8.0
# 7     NaN
# dtype: float64

# %%
"""
    :key参数使用
"""
s = pd.Series([1,4,6,8,-1,4,-56,np.nan,2])

sort_s = s.sort_values(key = lambda x:x**2)
print(sort_s)
# Out:
# 0     1.0
# 4    -1.0
# 8     2.0
# 1     4.0
# 5     4.0
# 2     6.0
# 3     8.0
# 6   -56.0
# 7     NaN
# dtype: float64

# %%
"""
    按照值对dataframe进行排序
    dataframe.sort_values(by, axis=0, ascending=True,
     inplace=False,kind='quicksort', na_position='last',
      ignore_index=False,key=None)
    by: 排序的列名或列名列表
    axis ： 0 index  1 columns
   ascending：True为升序，False为降序
   inplace：是否在原始dataframe中操作
   kind ： 排序算法
        quicksort：速度最快的，性能平均 但不稳定，最坏的情况下性能较差
        mergesort： 稳定的排序算法，性能较好，但是空间复杂度高
        heapsort: 空间效率较高，但不稳定
        stable： 稳定的排序算法，由mergesort和timesort实现
   na_position: 决定NaN值的放置位置  first放在首位  last放在尾部
   ignore_index： 为True则重置索引
   key：传入函数地址   如果指定，则这个函数将在排序之前应用于每个值，并且排序将基于这些函数返回的值。
"""

df = pd.DataFrame(
    {
        'col1':['a','b','c',np.nan,'d','c'],
        'col2':[2,1,4,8,7,9],
        'col3':[0,1,9,4,2,3],
        'col4':['a','b','c','d','e','f'],
    }
)

print(df)
# Out:
#   col1  col2  col3 col4
# 0    a     2     0    a
# 1    b     1     1    b
# 2    c     4     9    c
# 3  NaN     8     4    d
# 4    d     7     2    e
# 5    c     9     3    f

# %%
print(df.sort_values(by='col1'))
# Out:
#   col1  col2  col3 col4
# 0    a     2     0    a
# 1    b     1     1    b
# 2    c     4     9    c
# 5    c     9     3    f
# 4    d     7     2    e
# 3  NaN     8     4    d

# %%
# 对多列进行排序
print(df.sort_values(by=['col1','col2'],ascending=[True,False]))
# Out:
#   col1  col2  col3 col4
# 0    a     2     0    a
# 1    b     1     1    b
# 5    c     9     3    f
# 2    c     4     9    c
# 4    d     7     2    e
# 3  NaN     8     4    d
